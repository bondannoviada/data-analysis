# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y=[1,5,6]
z=[7,4,3]

# %%
plt.plot(x,y)
plt.title("grafik sederhana")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(x,z)
plt.legend(["this is Y", "this is Z"])

# %%
sample_data = pd.read_csv("sample_data.csv")

# %%
sample_data
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
sample_data.column_a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: column_a, dtype: int64

# %%
sample_data.column_a.iloc[2]
# Out:
# 3

# %%
countries = pd.read_csv("countries.csv")

# %%
plt.plot(sample_data.column_a, sample_data.column_b,'o')

# %%
countries
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
us = countries[countries.country == "United States"]
china = countries[countries.country == "China"]

# %%
us
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
countries.country == "United States"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
plt.plot(us.year, us.population / 10**6)
plt.plot(china.year, china.population / 10**6)
plt.legend(["US","China"])
plt.xlabel("Year")
plt.ylabel("Population")
# Out:
# Text(0, 0.5, 'Population')

# %%
covid_world_data = pd.read_csv("owid-covid-data.csv")

# %%
covid_world_data
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# ...        ...            ...         ...          ...        ...
# 20123      NaN  International  2020-02-28          705          0
# 20124      NaN  International  2020-02-29          705          0
# 20125      NaN  International  2020-03-01          705          0
# 20126      NaN  International  2020-03-02          705          0
# 20127      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0                 0           0                   18.733
# ...

# %%
us = countries[countries.country == "United States"]

# %%
indo_covid = covid_world_data[covid_world_data.location == "Indonesia"]
china_covid = covid_world_data[covid_world_data.location == "China"]

# %%
china_covid
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 3476      CHN    China  2019-12-31           27         27             0
# 3477      CHN    China  2020-01-01           27          0             0
# 3478      CHN    China  2020-01-02           27          0             0
# 3479      CHN    China  2020-01-03           44         17             0
# 3480      CHN    China  2020-01-04           44          0             0
# ...       ...      ...         ...          ...        ...           ...
# 3620      CHN    China  2020-05-23        84081          2          4638
# 3621      CHN    China  2020-05-24        84084          3          4638
# 3622      CHN    China  2020-05-25        84095         11          4638
# 3623      CHN    China  2020-05-26        84102          7          4638
# 3624      CHN    China  2020-05-27        84103          1          4638
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
plt.figure(figsize=(200, 50))
plt.plot(indo_covid.date, indo_covid.total_cases / 100, "o")
plt.plot(indo_covid.date, indo_covid.total_deaths / 100, "o")
plt.plot(china_covid.date, china_covid.total_cases / 100, "o")
plt.plot(china_covid.date, china_covid.total_deaths / 100, "o")
plt.legend(["kasus indo", "kematian indo", "kasus cina", "kematian cina"])

# %%
indo_covid
# Out:
#      iso_code   location        date  total_cases  new_cases  total_deaths  \
# 8440      IDN  Indonesia  2019-12-31            0          0             0
# 8441      IDN  Indonesia  2020-01-01            0          0             0
# 8442      IDN  Indonesia  2020-01-02            0          0             0
# 8443      IDN  Indonesia  2020-01-03            0          0             0
# 8444      IDN  Indonesia  2020-01-04            0          0             0
# ...       ...        ...         ...          ...        ...           ...
# 8577      IDN  Indonesia  2020-05-23        20796        634          1326
# 8578      IDN  Indonesia  2020-05-24        21745        949          1351
# 8579      IDN  Indonesia  2020-05-25        22271        526          1372
# 8580      IDN  Indonesia  2020-05-26        22750        479          1391
# 8581      IDN  Indonesia  2020-05-27        23165        415          1418
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
indo_covid_feb = indo_covid[indo_covid.new_cases != 0]

# %%
indo_covid_feb
# Out:
#      iso_code   location        date  total_cases  new_cases  total_deaths  \
# 8502      IDN  Indonesia  2020-03-02            2          2             0
# 8503      IDN  Indonesia  2020-03-07            4          2             0
# 8504      IDN  Indonesia  2020-03-09            6          2             0
# 8505      IDN  Indonesia  2020-03-11           19         13             0
# 8506      IDN  Indonesia  2020-03-12           34         15             1
# ...       ...        ...         ...          ...        ...           ...
# 8577      IDN  Indonesia  2020-05-23        20796        634          1326
# 8578      IDN  Indonesia  2020-05-24        21745        949          1351
# 8579      IDN  Indonesia  2020-05-25        22271        526          1372
# 8580      IDN  Indonesia  2020-05-26        22750        479          1391
# 8581      IDN  Indonesia  2020-05-27        23165        415          1418
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# ...

# %%
covid_world_data
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# ...        ...            ...         ...          ...        ...
# 20123      NaN  International  2020-02-28          705          0
# 20124      NaN  International  2020-02-29          705          0
# 20125      NaN  International  2020-03-01          705          0
# 20126      NaN  International  2020-03-02          705          0
# 20127      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0                 0           0                   18.733
# ...
